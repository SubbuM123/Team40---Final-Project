# %%
import recsys_ii
import inv_index

import numpy as np
import nltk
import pandas as pd
from nltk.corpus import stopwords

from collections import Counter
import math
import time

# %%
target_idx = 57917
ks = [1, 1.2, 1.4, 1.5, 1.6, 1.8]
vocab_sizes = [500, 1000, 1500]
v = 15
for k in ks:
    ri = inv_index.InvInd(bm25_k = k, top_words=15)
    ri.preprocess_data("abstract")
    ri.build_vocab("abstract")
    ri.compute_IDF("abstract")
    ri.preprocess_data("title")
    ri.build_vocab("title")
    ri.compute_IDF("title")
    ri.inverted_index()
    print("Done with ii, starting testing")
    # for v in vocab_sizes:
    rs = recsys_ii.RecSys_II(bm25_k=k, top_words=v)
    rs.build_vocab("abstract")
    rs.build_vocab("title")
    qt = "Implicit semantic text retrieval and distributed implementation for rural medical care"
    ss = rs.similarity_ranking(qt, qt)
    top100_indices = np.argsort(ss)[-100:][::-1]

    if target_idx in top100_indices:
        rank = np.where(top100_indices == target_idx)[0][0] + 1  # Rank is 1-based index
        reciprocal_rank = 1 / rank
        with open("hp.txt", "a") as f:
            f.write("k: " + str(k) + "\n")
            f.write("vocab size: " + str(v) + "\n")
            f.write("MRR: " + str(reciprocal_rank) + "\n")
            f.write("-----------------------------------------------------------------------\n")
    print("Done with the iteration")
# Out:
# 16
# 60000
# 16
# Done with ii, starting testing
# 1000
# 1000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 20
#      18 rs.build_vocab("title")
#      19 qt = "Implicit semantic text retrieval and distributed implementation for rural medical care"
# ---> 20 ss = rs.similarity_ranking(qt, qt)
#      21 top100_indices = np.argsort(ss)[-100:][::-1]
#      23 if target_idx in top100_indices:
#
# File c:\Projects\Team40---Final-Project\recsys_ii.py:154, in RecSys_II.similarity_ranking(self, query_title, query_abstract)
#     152 similarity_scores = []
#     153 for i in range(self.num_rows):
# --> 154     score = 0.66 * self.tfidf_score(q_title, self.title_idf[i], "title") + 0.33 * self.tfidf_score(q_abstract, self.abstract_idf[i], "abstract")
#     155     similarity_scores.append(score)
#     157 return np.array(similarity_scores)
#
# File c:\Projects\Team40---Final-Project\recsys_ii.py:143, in RecSys_II.tfidf_score(self, query_vec, doc_vec, title_or_abstract)
#     142 def tfidf_score(self,query_vec,doc_vec, title_or_abstract):
# --> 143     relevance = np.dot(query_vec, doc_vec)
#     144     return relevance
#
# ValueError: shapes (1000,) and (500,) not aligned: 1000 (dim 0) != 500 (dim 0)
